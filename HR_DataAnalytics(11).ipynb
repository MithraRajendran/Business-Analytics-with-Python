# %%
import pandas as pd

# %%
df=pd.read_csv("/content/HRDataset_v14.csv")

# %%
a=df.loc[df["Position"]=="Production Technician I"]
print(a.count())
# Out:
# Employee_Name                 137
# EmpID                         137
# MarriedID                     137
# MaritalStatusID               137
# Gender                        137
# EmpStatusID                   137
# DeptID                        137
# PerfScoreID                   137
# FromDiversityJobFairID        137
# Salary                        137
# Termd                         137
# PositionID                    137
# Position                      137
# State                         137
# Zip                           137
# DOB                           137
# Sex                           137
# MaritalDesc                   137
# CitizenDesc                   137
# DateofHire                    137
# DateofTermination              52
# TermReason                    137
# EmploymentStatus              137
# Department                    137
# ManagerName                   137
# ManagerID                     133
# RecruitmentSource             137
# ...

# %%
a=df.loc[df["Gender"]=="Male"]
print(a.count())
# Out:
# Employee_Name                 193
# EmpID                         193
# MarriedID                     193
# MaritalStatusID               193
# Gender                        194
# EmpStatusID                   193
# DeptID                        193
# PerfScoreID                   193
# FromDiversityJobFairID        193
# Salary                        193
# Termd                         193
# PositionID                    193
# Position                      193
# State                         193
# Zip                           193
# DOB                           193
# Sex                           193
# MaritalDesc                   193
# CitizenDesc                   193
# DateofHire                    193
# DateofTermination              64
# TermReason                    193
# EmploymentStatus              193
# Department                    193
# ManagerName                   193
# ManagerID                     187
# RecruitmentSource             193
# ...

# %%
a=df.loc[df["ManagerName"]=="Michael Albert"]
print(a.count())
# Out:
# Employee_Name                 22
# EmpID                         22
# MarriedID                     22
# MaritalStatusID               22
# Gender                        22
# EmpStatusID                   22
# DeptID                        22
# PerfScoreID                   22
# FromDiversityJobFairID        22
# Salary                        22
# Termd                         22
# PositionID                    22
# Position                      22
# State                         22
# Zip                           22
# DOB                           22
# Sex                           22
# MaritalDesc                   22
# CitizenDesc                   22
# DateofHire                    22
# DateofTermination              9
# TermReason                    22
# EmploymentStatus              22
# Department                    22
# ManagerName                   22
# ManagerID                     22
# RecruitmentSource             22
# PerformanceScore              22
# ...

# %%
df.loc[df["EmploymentStatus"]=="Active"]
# Out:
#            Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0    Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 3           Alagbe,Trina  10088.0        1.0              1.0  Female
# 5      Anderson, Linda    10002.0        0.0              0.0    Male
# 6        Andreola, Colby  10194.0        0.0              0.0  Female
# 7            Athwal, Sam  10062.0        0.0              4.0    Male
# ..                   ...      ...        ...              ...     ...
# 305        Wolk, Hang  T  10174.0        0.0              0.0  Female
# 306       Woodson, Jason  10135.0        0.0              0.0    Male
# 308     Zamora, Jennifer  10010.0        0.0              0.0    Male
# 309          Zhou, Julia  10043.0        0.0              0.0    Male
# 310        Zima, Colleen  10271.0        0.0              4.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# ...

# %%
df.loc[df["MaritalDesc"]=="Married"]
# Out:
#                 Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 1    Ait Sidi, Karthikeyan     10084.0        1.0              1.0    Male
# 2           Akinkuolie, Sarah  10196.0        1.0              1.0    Male
# 3                Alagbe,Trina  10088.0        1.0              1.0  Female
# 10       Baczenski, Rachael    10252.0        1.0              1.0    Male
# 11            Barbara, Thomas  10242.0        1.0              1.0  Female
# ..                        ...      ...        ...              ...     ...
# 288           Valentin,Jackie  10205.0        1.0              1.0    Male
# 292           Voldemort, Lord  10118.0        1.0              1.0  Female
# 293             Volk, Colleen  10022.0        1.0              1.0    Male
# 296      Wallace, Courtney  E  10274.0        1.0              1.0    Male
# 301             Wilber, Barry  10048.0        1.0              1.0  Female
#
# ...

# %%
a=df.loc[df["EmploymentStatus"]=="Active"]
a.loc[a["MonthlyIncome"]<60000]
# Out:
#            Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0    Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 3           Alagbe,Trina  10088.0        1.0              1.0  Female
# 5      Anderson, Linda    10002.0        0.0              0.0    Male
# 6        Andreola, Colby  10194.0        0.0              0.0  Female
# 7            Athwal, Sam  10062.0        0.0              4.0    Male
# ..                   ...      ...        ...              ...     ...
# 305        Wolk, Hang  T  10174.0        0.0              0.0  Female
# 306       Woodson, Jason  10135.0        0.0              0.0    Male
# 308     Zamora, Jennifer  10010.0        0.0              0.0    Male
# 309          Zhou, Julia  10043.0        0.0              0.0    Male
# 310        Zima, Colleen  10271.0        0.0              4.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# ...

# %%
a=df.loc[df["Position"]=="Production Technician II"]
b=a["EngagementSurvey"].max()
a.loc[a["EngagementSurvey"]==b]
# Out:
#           Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 123    Hankard, Earnest  10074.0        0.0              0.0    Male
# 127  Hendrickson, Trina  10075.0        0.0              0.0    Male
# 177   Manchester, Robyn  10077.0        1.0              1.0    Male
# 178      Mancuso, Karen  10073.0        1.0              1.0  Female
# 182     Carthy, B'rigit  10076.0        0.0              0.0  Female
# 206     Oliver, Brooke   10078.0        1.0              1.0    Male
# 304  Winthrop, Jordan    10033.0        0.0              0.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID   Salary  ...  \
# 123          1.0     5.0          3.0                     0.0  64246.0  ...
# 127          5.0     5.0          3.0                     0.0  68099.0  ...
# 177          2.0     5.0          3.0                     0.0  62385.0  ...
# 178          5.0     5.0          3.0                     0.0  68407.0  ...
# ...

# %%
a=df["Salary"].max()
df.loc[df["Salary"]==a]
# Out:
#     Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  EmpStatusID  \
# 150   King, Janet  10089.0        1.0              1.0  Female          1.0
#
#      DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# 150     2.0          3.0                     0.0  250000.0  ...
#
#      PerformanceRating  StandardHours StockOptionLevel TotalWorkingYears  \
# 150                  3             80                1                20
#
#      TrainingTimesLastYear WorkLifeBalance YearsAtCompany YearsInCurrentRole  \
# 150                      2               3             20                  7
#
#     YearsSinceLastPromotion YearsWithCurrManager
# 150                       2                   13
#
# [1 rows x 56 columns]

# %%
avg=df["Salary"].mean()
df.loc[df["Salary"]<avg]
# Out:
#              Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0      Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 2        Akinkuolie, Sarah  10196.0        1.0              1.0    Male
# 3             Alagbe,Trina  10088.0        1.0              1.0  Female
# 4         Anderson, Carol   10069.0        0.0              2.0    Male
# 5        Anderson, Linda    10002.0        0.0              0.0    Male
# ..                     ...      ...        ...              ...     ...
# 303  Williams, Jacquelyn    10264.0        0.0              0.0    Male
# 305          Wolk, Hang  T  10174.0        0.0              0.0  Female
# 306         Woodson, Jason  10135.0        0.0              0.0    Male
# 307     Ybarra, Catherine   10301.0        0.0              0.0  Female
# 310          Zima, Colleen  10271.0        0.0              4.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID   Salary  ...  \
# ...

# %%
avg=df["Salary"].mean()
a=df.loc[df["Salary"]<avg]
a.loc[a["EmpSatisfaction"]<3]
# Out:
#           Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 29           Brown, Mia  10238.0        1.0              1.0  Female
# 54    Corleone, Michael  10282.0        0.0              2.0  Female
# 69      Desimone, Carl   10310.0        1.0              1.0    Male
# 72    Dietrich, Jenna    10304.0        0.0              0.0    Male
# 83       Erilus, Angela  10299.0        0.0              3.0  Female
# 188         Miller, Ned  10298.0        0.0              0.0    Male
# 205        O'hare, Lynn  10303.0        0.0              0.0  Female
# 263    Sparks, Taylor    10302.0        1.0              1.0  Female
# 267  Stansfield, Norman  10307.0        1.0              1.0    Male
# 307  Ybarra, Catherine   10301.0        0.0              0.0  Female
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID   Salary  ...  \
# 29           1.0     1.0          3.0                     1.0  63000.0  ...
# ...

# %%
import matplotlib.pyplot as plt
x=df["DistanceFromHome"]
y=df["EmpSatisfaction"]
plt.scatter(x,y)
